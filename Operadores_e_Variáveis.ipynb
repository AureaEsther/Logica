# %%
#Adição
2+10
# Out:
# 12

# %%
#Subtração
10-2
# Out:
# 8

# %%
#Multiplicação
10*2
# Out:
# 20

# %%
#Divisão
10/2
# Out:
# 5.0

# %%
#Divisão inteira
10//2
# Out:
# 5

# %%
#Resto da divisão
10%2
# Out:
# 0

# %%
#Potenciação
10**2
# Out:
# 100

# %% [markdown]
# Operadores Relacionais

# %%
#Menor que
2<3
# Out:
# True

# %%
#Maior que
3>2
# Out:
# True

# %%
#Menor ou igual a
2<=3
# Out:
# True

# %%
#Maior ou igual a
3>=2
# Out:
# True

# %%
#Igual a
3==3
# Out:
# True

# %%
#Diferente
3!= 2
# Out:
# True

# %% [markdown]
# Operadores Lógicos
#
# *   And
# *   Or
# *   Not
